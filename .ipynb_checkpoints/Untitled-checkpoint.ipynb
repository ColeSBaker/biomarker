# %%
import os
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
# from biomarker.data_collection import *
from data_collection import *
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
# import seaborn as sns; sns.set()
from sklearn.decomposition import PCA
from ensemble import * 
from sklearn.manifold import TSNE

# %%
##run PCA's on each variable
def make_PCA(data,n):
    pca = PCA(n_components=n)
    pca.fit(data)
    X_pca = pca.transform(data)
#     print(pca.explained_variance_ratio_)
    plt.plot(np.cumsum(pca.explained_variance_ratio_))
    return X_pca

# %%
X1_pca = make_PCA(x1,30)
# Out:
# [0.53881455 0.12890538 0.07575885 0.03668535 0.02653274 0.02278817
#  0.01948184 0.01404536 0.01171141 0.01009324 0.00887253 0.00740858
#  0.00644645 0.00601888 0.0055401  0.00514058 0.0048985  0.00438784
#  0.00384047 0.00356864 0.00313005 0.00299327 0.00286746 0.00273425
#  0.0026904  0.00232056 0.00211004 0.00198935 0.00186159 0.00180347]

# %%
X4_pca = make_PCA(x4,30)
# Out:
# [0.11772143 0.10093023 0.07757754 0.061122   0.05988243 0.05110509
#  0.04484634 0.04193146 0.03752393 0.03680767 0.03411033 0.0289323
#  0.0274691  0.02502916 0.02476816 0.02214941 0.01893205 0.01752774
#  0.01678274 0.01568271 0.01411904 0.01313837 0.01244499 0.01116049
#  0.01069764 0.00923116 0.00824047 0.00742591 0.00707123 0.00624708]

# %%
X5_pca = make_PCA(x5,30)
# Out:
# [4.09085764e-01 1.26462895e-01 7.35603408e-02 6.39105068e-02
#  4.68710381e-02 4.44200285e-02 4.08562532e-02 3.37763718e-02
#  2.76449231e-02 2.08759317e-02 1.98696030e-02 1.70161414e-02
#  1.25441707e-02 1.11274560e-02 9.42275483e-03 8.41879534e-03
#  7.82234497e-03 5.68091136e-03 4.84737345e-03 4.22202170e-03
#  2.89935637e-03 2.39711575e-03 2.12074338e-03 2.01014123e-03
#  9.17868502e-04 6.19243598e-04 1.99823792e-04 8.65927350e-05
#  7.02074684e-05 4.78369631e-05]

# %%
X6_pca = make_PCA(x6,30)
# Out:
# [2.12369362e-01 1.89943087e-01 1.64255508e-01 1.21621555e-01
#  8.36559136e-02 6.60309157e-02 4.43789645e-02 2.33798017e-02
#  1.79741052e-02 1.49591444e-02 9.48802207e-03 9.16354434e-03
#  7.70331364e-03 6.41966810e-03 5.94449583e-03 5.78540234e-03
#  4.14943453e-03 3.25410096e-03 2.95041132e-03 2.11767189e-03
#  1.45159172e-03 1.25562697e-03 9.22735217e-04 7.04383767e-04
#  8.59356445e-05 3.40573075e-05 6.06774757e-07 1.15830762e-07
#  5.10461901e-08 4.19632160e-08]

# %%
X7_pca = make_PCA(x7,30)
# Out:
# [2.12380360e-01 1.89944995e-01 1.64254032e-01 1.21629121e-01
#  8.36547001e-02 6.60370627e-02 4.43709832e-02 2.33771054e-02
#  1.79717596e-02 1.49545387e-02 9.48719589e-03 9.16094813e-03
#  7.70234220e-03 6.41983104e-03 5.94320127e-03 5.78503861e-03
#  4.14960575e-03 3.25487217e-03 2.95001583e-03 2.11743342e-03
#  1.45151811e-03 1.25558863e-03 9.22287129e-04 7.04344242e-04
#  8.60252928e-05 3.40588120e-05 5.98476732e-07 1.10299795e-07
#  5.03867009e-08 4.18432981e-08]

# %%
M_pca = make_PCA(master,10)
# Out:
# [7.52473181e-01 2.36758963e-01 8.85516787e-03 8.92312261e-04
#  2.86501616e-04 1.84192138e-04 1.64489063e-04 1.26288878e-04
#  9.07976076e-05 5.84268994e-05]

# %%
#put output k into buckets for coloring

b = lambda x: -1 if x<2 else (0 if x<5 else (1 if x<10 else 2))
# b = lambda x: -2 if x<2 else (-1 if x<4 else (0 if x<6 else (1 if x<10 else 2)))
buckets = np.array([b(xi) for xi in y])

# %%
def norm(data):
    new = data.copy()
    for i in range(data.shape[1]):
        var = data[:,i]
        h = var.max()
        l = var.min()
        new_var = new[:,i]
        for p in range(var.shape[0]):
            x = var[p]
            new_var[p] = (x-l)/(h-l)
        new[:,i]= new_var
    return new

# %%
def plot(data):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(data[:, 0], data[:, 1], data[:, 2], c=buckets, marker='o',cmap="RdYlBu_r")
    X1_norm = norm(X1_pca)
    plt.show()
    plt.scatter(data[:, 0], data[:, 1], edgecolor='none', alpha= 1 , c=buckets,cmap="RdYlBu_r")
    
    plt.colorbar()

# %%
##Plot PCA in 2-d/ 3-d
plot(X1_pca)
X1_norm= norm(X1_pca)

# %%
plot(X4_pca)
X4_norm = norm(X4_pca)

# %%
plot(X5_pca)
X5_norm = norm(X5_pca)

# %%
plot(X6_pca)
X6_norm = norm(X6_pca)

# %%
plot(X7_pca)
X7_norm = norm(X7_pca)

# %%
plot(M_pca)
M_norm = norm(M_pca)

# %%
def runTSNE(data, y, dims, perp, i):
    tsne = TSNE(perplexity=perp, n_iter=i)
    tsne_results = tsne.fit_transform(data[:,:dims])
    plt.scatter(tsne_results[:, 0], tsne_results[:, 1], edgecolor='none', alpha= .8 , c=buckets,cmap="RdYlBu_r")
    plt.colorbar()
    return tsne_results

# %%
TSNE1 = runTSNE(X1_norm,buckets, 5,40,1000)

# %%
##No clear distinction
TSNE4 = runTSNE(X4_norm,buckets, 15,40,1000)

# %%
TSNE5 = runTSNE(X5_norm,buckets, 20,50,5000)

# %%
TSNE6 = runTSNE(X6_norm,buckets, 20,50,1000)

# %%
TSNE7 = runTSNE(X7_norm,buckets, 20,80,1000)

# %%
TSNEM = runTSNE(M_norm,buckets, 30,30,1000)
